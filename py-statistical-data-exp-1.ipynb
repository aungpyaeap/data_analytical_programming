# %%
import mysql.connector as sql
import pandas as pd

db_connection = sql.connect(host='remotemysql.com',database='emJ28753Ns',user='emJ28753Ns',password='JrwDFnhpmX')
db_cursor = db_connection.cursor()

table_rows = pd.read_sql('SELECT * FROM HBAT', con=db_connection)
table_rows.head(5)
# Out:
#    x1  x2  x3  x4  x5   x6   x7   x8   x9  x10  ...  x14  x15  x16  x17  x18  \
# 0   2   0   1   1   1  8.5  3.9  2.5  5.9  4.8  ...  4.7  4.3  5.0  5.1  3.7
# 1   3   1   0   0   0  8.2  2.7  5.1  7.2  3.4  ...  5.5  4.0  3.9  4.3  4.9
# 2   3   0   1   1   1  9.2  3.4  5.6  5.6  5.4  ...  6.2  4.6  5.4  4.0  4.5
# 3   1   1   1   1   0  6.4  3.3  7.0  3.7  4.7  ...  7.0  3.6  4.3  4.1  3.0
# 4   2   0   1   0   1  9.0  3.4  5.2  4.6  2.2  ...  6.1  4.5  4.5  3.5  3.5
#
#    x19  x20  x21   x22  x23
# 0  8.2  8.0  8.4  65.1    1
# 1  5.7  6.5  7.5  67.1    0
# 2  8.9  8.4  9.0  72.1    1
# 3  4.8  6.0  7.2  40.1    0
# 4  7.1  6.6  9.0  57.1    0
#
# [5 rows x 23 columns]

# %%
table_rows.describe()
# Out:
#                x1          x2          x3          x4         x5          x6  \
# count  100.000000  100.000000  100.000000  100.000000  100.00000  100.000000
# mean     2.010000    0.480000    0.510000    0.610000    0.43000    7.810000
# std      0.810225    0.502117    0.502418    0.490207    0.49757    1.396279
# min      1.000000    0.000000    0.000000    0.000000    0.00000    5.000000
# 25%      1.000000    0.000000    0.000000    0.000000    0.00000    6.575000
# 50%      2.000000    0.000000    1.000000    1.000000    0.00000    8.000000
# 75%      3.000000    1.000000    1.000000    1.000000    1.00000    9.100000
# max      3.000000    1.000000    1.000000    1.000000    1.00000   10.000000
#
#                x7          x8          x9         x10  ...         x14  \
# count  100.000000  100.000000  100.000000  100.000000  ...  100.000000
# mean     3.672000    5.365000    5.442000    4.010000  ...    6.043000
# ...

# %%
corr = table_rows.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_bc54ead2_af6a_11e9_874a_645d869d4977row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_bc54ead2_af6a_11e9_874a_645d869d4977row0_col1 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_bc54ead2_af6a_11e9_874a_645d869d4977row0_col2 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_bc54ead2_af6a_11e9_874a_645d869d4977row0_col3 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_bc54ead2_af6a_11e9_874a_645d869d4977row0_col4 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_bc54ead2_af6a_11e9_874a_645d869d4977row0_col5 {
#             background-color:  #f6a385;
#             color:  #000000;
#         }    #T_bc54ead2_af6a_11e9_874a_645d869d4977row0_col6 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
# ...

# %%
corr.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style  type="text/css" >
#     #T_d2c27076_af6a_11e9_bdc2_645d869d4977row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d2c27076_af6a_11e9_bdc2_645d869d4977row0_col1 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_d2c27076_af6a_11e9_bdc2_645d869d4977row0_col2 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_d2c27076_af6a_11e9_bdc2_645d869d4977row0_col3 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_d2c27076_af6a_11e9_bdc2_645d869d4977row0_col4 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_d2c27076_af6a_11e9_bdc2_645d869d4977row0_col5 {
#             background-color:  #f5a081;
#             color:  #000000;
#         }    #T_d2c27076_af6a_11e9_bdc2_645d869d4977row0_col6 {
#             background-color:  #a1c0ff;
#             color:  #000000;
# ...

# %%
table_rows['x23'].value_counts().plot('barh')

# %%
table_rows['x10'].hist() #horizontal bar plot

# %%
table_rows['x10'].hist(bins = 30) #add granularity
